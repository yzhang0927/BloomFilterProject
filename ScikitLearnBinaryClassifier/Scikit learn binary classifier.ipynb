# %%
import numpy as np
with open("1.txt", "r") as f:
    raw_data = f.read()
data = raw_data.split(' ')

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-454b17d69cd5> in <module>
# ----> 1 data = np.array([int(d) for d in data]) # this will give you array of shape (N, )
#
# <ipython-input-6-454b17d69cd5> in <listcomp>(.0)
# ----> 1 data = np.array([int(d) for d in data]) # this will give you array of shape (N, )
#
# ValueError: invalid literal for int() with base 10: ''

# %%
data = [element for element in data if element != '']

# %%
data
# Out:
# ['14',
#  '15',
#  '16',
#  '17',
#  '19',
#  '25',
#  '28',
#  '30',
#  '39',
#  '47',
#  '48',
#  '49',
#  '50',
#  '51',
#  '54',
#  '55',
#  '58',
#  '62',
#  '65',
#  '66',
#  '68',
#  '70',
#  '74',
#  '77',
#  '86',
#  '87',
#  '107',
#  '113',
#  '114',
#  '115',
#  '128',
#  '135',
#  '136',
#  '137',
#  '140',
#  '143',
#  '145',
#  '146',
#  '151',
#  '156',
#  '159',
#  '161',
#  '171',
#  '176',
#  '177',
#  '178',
#  '180',
#  '181',
#  '182',
#  '188',
#  '197',
#  '200',
#  '205',
#  '208',
#  '218',
#  '226',
#  '227',
#  '233',
#  '237',
#  '245',
#  '260',
#  '264',
#  '265',
#  '266',
#  '267',
#  '268',
#  '270',
#  '280',
#  '286',
#  '291',
#  '292',
#  '305',
#  '310',
#  '313',
#  '314',
#  '323',
#  '326',
#  '329',
#  '335',
#  '336',
#  '341',
#  '344',
#  '345',
#  '346',
#  '347',
#  '376',
#  '390',
#  '404',
#  '405',
#  '417',
#  '420',
#  '426',
#  '437',
#  '441',
#  '442',
#  '445',
#  '447',
#  '456',
#  '457',
#  '462',
#  '471',
#  '477',
# ...

# %%
data = np.array([int(d) for d in data]) # this will give you array of shape (N, )

# %%
data
# Out:
# array([      14,       15,       16, ..., 25205167, 25205169, 25205172])

# %%
from sklearn import svm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-15-264c9a795a14> in <module>
# ----> 1 from sklearn import svm
#
# ModuleNotFoundError: No module named 'sklearn'
